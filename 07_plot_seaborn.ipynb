# %% [markdown]
# >Ejemplos de uso del paquete seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def read_csv_to_dataframe(file_path):
    try:
        df = pd.read_csv(file_path, sep=';')
        return df
    except Exception as e:
        print(f"Error reading the cvs file: {e}")
        return None

# %%
terminos_df= read_csv_to_dataframe("Terminos_lagoon_TA_DIC_2023_RawData.csv")

# %%
#Crear mi propia paleta de colores
my_colors = ["#5ec962", "#3b528b"]

# %%
#Añadir un arreglo
sns.set(font_scale=2, style="ticks", palette= my_colors)

# %%
#Boxplot con catplot usando seaborn
ax = sns.catplot(data=terminos_df,
                 x="area", y="ta_micromol_kg",
                hue="season", col="estuary",
                kind="box", 
                height=7, aspect=1)

  
ax.set(xlabel='', ylabel=' TA ($\mu mol \; kg^{-1}$)')

ax.set_titles(col_template="{col_name}", row_template="{row_name}")

plt.setp(ax._legend.get_title(), fontsize=20)

sns.despine(top=False,right=False)

plt.show()

# %%
#plot de violin con catplot usando seaborn
ax = sns.catplot(data=terminos_df, 
                x="area", y="ta_micromol_kg",
                hue="season", col="estuary", 
                kind="violin", 
                height=7, aspect=1)

  
ax.set(xlabel='', ylabel=' TA ($\mu mol \; kg^{-1}$)')

ax.set_titles(col_template="{col_name}", row_template="{row_name}")

plt.setp(ax._legend.get_title(), fontsize=20)

sns.despine(top=False,right=False)

plt.show()

# %%
#Plot de puntos para 3 variables categoricas, area, temporada y estuario y una variable dependiente, TA
ax = sns.catplot(
    data=terminos_df, x="season", 
    y="ta_micromol_kg", hue="estuary", col="area",
    capsize=.2, palette="YlGnBu_d", errorbar="se",
    kind="point", height=6, aspect=.75,
)
ax.despine(left=True)

ax.set(xlabel='', ylabel=' TA ($\mu mol \; kg^{-1}$)')

ax.set_titles(col_template="{col_name}", row_template="{row_name}")

plt.setp(ax._legend.get_title(), fontsize=20)

sns.despine(top=False,right=False)

plt.show()

# %%
# Scatterplot (lmplot) de DIC vs Salinidad por estuario y temporadas

ax = sns.lmplot(x="sal_psu", y="ta_micromol_kg",
                hue="season",col="estuary",
                data=terminos_df, 
                height=7, aspect=1)

ax.set(xlabel='Salinity (PSU)', ylabel=' DIC ($\mu mol \; kg^{-1}$)')

ax.set_titles(col_template="{col_name}", row_template="{row_name}")

plt.setp(ax._legend.get_title(), fontsize=20)

sns.despine(top=False,right=False)

plt.show()

# %% [markdown]
# Tarea 07

# %%
#cambiar unidades de una figura
#Boxplot con catplot usando seaborn
terminos_df['ta_micromol_kg']=terminos_df['ta_micromol_kg']/1000

# %%
ax = sns.catplot(data=terminos_df,
                 x="area", y="ta_micromol_kg",
                hue="season", col="estuary",
                kind="box", 
                height=7, aspect=1)

  
ax.set(xlabel='', ylabel=' TA ( mmol \; kg^{-1}$)')

ax.set_titles(col_template="{col_name}", row_template="{row_name}")

plt.setp(ax._legend.get_title(), fontsize=20)

sns.despine(top=False,right=False)

plt.show()

# %%
#Análisis exploratorio de variables morfologicas de tres especies de pnguinos

sns.set_theme(style="ticks")

df = sns.load_dataset("penguins")
sns.pairplot(df, hue="species")

# %%
#Gráfico de estimación de kernel para mostrar los datos suavizados de petalos y tepalos de dos especies de plantas
sns.set_theme(style="darkgrid")
iris = sns.load_dataset("iris")

# Set up the figure
f, ax = plt.subplots(figsize=(8, 8))
ax.set_aspect("equal")

# Draw a contour plot to represent each bivariate density
sns.kdeplot(
    data=iris.query("species != 'versicolor'"),
    x="sepal_width",
    y="sepal_length",
    hue="species",
    thresh=.1,
)
