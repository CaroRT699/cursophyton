# %% [markdown]
#  Prueba no paramétrica de U mann Whitney para comparación de dos muestras no pareadas

# %%
import pandas as pd
import numpy as np

# %%
def read_csv_to_dataframe(file_path):
    try:
        df = pd.read_csv(file_path, sep=';')
        return df
    except Exception as e:
        print(f"Error reading the cvs file: {e}")
        return None

# %%
terminos_df= read_csv_to_dataframe("Terminos_lagoon_TA_DIC_2023_RawData.csv")

# %%
#Crear función para la prueba

from scipy.stats import mannwhitneyu

def mann_whitney_test(data1, data2, alpha=0.05):
    """
    Performs the Mann-Whitney U test and prints U statistic, p-value, and result.
    """
    result = mannwhitneyu(data1, data2, alternative='two-sided')
    
    print(f"U statistic = {result.statistic}")
    print(f"p-value = {result.pvalue}")

    if result.pvalue < alpha:
        print("The difference is statistically significant.")
    else:
        print("The difference is not statistically significant.")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Create a box plot
sns.boxplot(x='season', y='ta_micromol_kg', data=terminos_df)
#sns.swarmplot(x='season', y='sal_psu', data=co2_data, color=".25")

# Add labels and title
plt.xlabel('Season')
plt.ylabel('TA (μmol/kg)')
plt.title('Box Plot of TA by Season')

# Show the plot
plt.show()

# %%
# Filter the TA data by season
ta_dry = terminos_df.loc[terminos_df["season"] == "Dry", "ta_micromol_kg"]
ta_rainy = terminos_df.loc[terminos_df["season"] == "Rainy", "ta_micromol_kg"]

# %%
# Perform the Mann-Whitney U test for TA between dry and rainy seasons
mann_whitney_test(ta_dry, ta_rainy)
# Out:
# U statistic = 2251.5
# p-value = 3.618607122062942e-12
# The difference is statistically significant.

# %%
# Create a box plot
sns.boxplot(x='season', y='sal_psu', data=terminos_df)
#sns.swarmplot(x='season', y='sal_psu', data=co2_data, color=".25")

# Add labels and title
plt.xlabel('Season')
plt.ylabel('Salinidad (PSU)')
plt.title('Box Plot of TA by Season')

# Show the plot
plt.show()

# %%
# Filter the TA data by season
sal_dry = terminos_df.loc[terminos_df["season"] == "Dry", "sal_psu"]
sal_rainy = terminos_df.loc[terminos_df["season"] == "Rainy", "sal_psu"]

# %%
mann_whitney_test(sal_dry, sal_rainy)
# Out:
# U statistic = 1660.0
# p-value = 0.003199701027350606
# The difference is statistically significant.

# %%
#Aunque hay diferencias observar mejor la distribucion de los datos
sns.boxplot(x='season', y='sal_psu', data=terminos_df)
sns.swarmplot(x='season', y='sal_psu', data=terminos_df, color=".25")

# Add labels and title
plt.xlabel('Season')
plt.ylabel('Salinity (PSU)')
plt.title('Box Plot of Salinity by Season')

# Show the plot
plt.show()

# %% [markdown]
# >Tarea 09_ Prueba no paramétrica de U mann Whitney

# %%
# DIC ENTRE AMBAS TEMPORADAS CLIMÁTICAS
dic_dry = terminos_df.loc[terminos_df["season"] == "Dry", "dic_micromol_kg"]
dic_rainy = terminos_df.loc[terminos_df["season"] == "Rainy", "dic_micromol_kg"]
tem_dry = terminos_df.loc[terminos_df["season"] == "Dry", "temp_c"]
tem_rainy = terminos_df.loc[terminos_df["season"] == "Rainy", "temp_c"]

# %%
mann_whitney_test(dic_dry, dic_rainy)
# Out:
# U statistic = 1942.5
# p-value = 1.1746695070093673e-06
# The difference is statistically significant.

# %%
sns.boxplot(x='season', y='dic_micromol_kg', data=terminos_df)
sns.swarmplot(x='season', y='dic_micromol_kg', data=terminos_df, color=".25")

# Add labels and title
plt.xlabel('Season')
plt.ylabel('DIC (micromol/kg)')
plt.title('Box Plot of DIC by Season')

# Show the plot
plt.show()

# %%
sns.violinplot(x='season', y='dic_micromol_kg', data=terminos_df)

plt.title('DIC Distribution by Season')
plt.xlabel('Season')
plt.ylabel('DIC (micromol/kg)')
plt.show()

# %%
mann_whitney_test(tem_dry, tem_rainy)
# Out:
# U statistic = 551.0
# p-value = 5.317160670684041e-06
# The difference is statistically significant.

# %%
sns.boxplot(x='season', y='temp_c', data=terminos_df)
sns.swarmplot(x='season', y='temp_c', data=terminos_df, color=".25")

# Add labels and title
plt.xlabel('Season')
plt.ylabel('Temperature (C°')
plt.title('Box Plot of Temperature by Season')

# Show the plot
plt.show()

# %%
sns.violinplot(x='season', y='temp_c', data=terminos_df)

plt.title('Temperature Distribution by Season')
plt.xlabel('Season')
plt.ylabel('Temperature (C°)')
plt.show()
